# %% [markdown]
# # Install and import

# %%
# !pip install git+https://github.com/batprem/price-loaders.git@fix/default-return-data-to-numerical
# Out:
# ...
#   Cloning https://github.com/batprem/price-loaders.git (to revision fix/default-return-data-to-numerical) to /tmp/pip-req-build-hg_6glee
#   Running command git clone --filter=blob:none --quiet https://github.com/batprem/price-loaders.git /tmp/pip-req-build-hg_6glee
#   Running command git checkout -b fix/default-return-data-to-numerical --track origin/fix/default-return-data-to-numerical
#   Switched to a new branch 'fix/default-return-data-to-numerical'
#   Branch 'fix/default-return-data-to-numerical' set up to track remote branch 'fix/default-return-data-to-numerical' from 'origin'.
#   Resolved https://github.com/batprem/price-loaders.git to commit e2731e78406ad42b8e4691abcaaffeb149d7df78
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...

# %%
from price_loaders.tradingview import load_asset_price

# %% [markdown]
# # Load stock price

# %%
df = load_asset_price("SET:TTB", 3650, "1D", None)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 df = load_asset_price("SET:TTB", 3650, "1D", None)
#       2 df
#
# File ~/miniconda3/envs/thairath/lib/python3.11/site-packages/price_loaders/tradingview.py:428, in load_asset_price(symbol, look_back_bars, time_frame, timezone)
#     415 """Run full process to scrape TradingView data
#     416
#     417 Args:
#    (...)
#     425     pd.DataFrame: return as a dataframe
#     426 """
#     427 chart = load_raw_data(symbol, look_back_bars, time_frame)
# --> 428 return aggregate_to_dataframe(chart, timezone)
#
# File ~/miniconda3/envs/thairath/lib/python3.11/site-packages/price_loaders/tradingview.py:406, in aggregate_to_dataframe(chart, timezone)
#     395     ohlcv = pd.concat(
#     396         [ohlcv.set_index("time"), pe_ratio.set_index("time")], axis=1
#     397     ).reset_index()
# ...

# %%
df

# %% [markdown]
# # Load index (SET)

# %%
df = load_asset_price("SET", 3650, "1D", None)
df
# Out:
#                           time        open        high         low       close
# 0    2008-12-24 09:00:00+07:00   439.01001   443.76001   438.16000   439.17001
# 1    2008-12-25 09:00:00+07:00   441.85001   444.64001   439.64001   444.64001
# 2    2008-12-26 09:00:00+07:00   445.73999   448.29001   444.37000   446.62000
# 3    2008-12-29 09:00:00+07:00   444.92001   446.70001   440.20999   446.70001
# 4    2008-12-30 09:00:00+07:00   448.41000   452.48999   446.85999   449.95999
# ...                        ...         ...         ...         ...         ...
# 3645 2023-12-22 09:00:00+07:00  1407.39000  1407.56990  1397.93010  1405.09000
# 3646 2023-12-25 09:00:00+07:00  1404.56010  1409.41000  1404.35000  1408.83000
# 3647 2023-12-26 09:00:00+07:00  1408.17000  1414.43990  1406.50000  1413.45000
# 3648 2023-12-27 09:00:00+07:00  1415.06010  1416.10000  1407.62000  1410.43010
# 3649 2023-12-28 09:00:00+07:00  1410.87000  1418.98000  1410.87000  1415.85000
#
# [3650 rows x 5 columns]

# %% [markdown]
# # Load TFEX (S501!)

# %%
df = load_asset_price("S501!", 3650, "1D", None)
df
# Out:
#                           time    open    high     low   close    volume
# 0    2014-10-31 09:45:00+07:00  1039.0  1056.0  1037.0  1054.9   70889.0
# 1    2014-11-03 09:45:00+07:00  1056.3  1059.8  1049.2  1052.6   65870.0
